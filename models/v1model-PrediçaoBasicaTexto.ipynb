# %%
import pandas as pd
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, classification_report

df = pd.read_csv('../data/processed/dataset_sintomas_risco_1000.csv')

#separando colunas de texto e risco
x = df['texto']
y = df['risco']

#separando dados de treino e teste
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

#aplicando TF-IDF
vetor = TfidfVectorizer()
x_train_vetor = vetor.fit_transform(x_train)
x_test_vetor = vetor.transform(x_test)


model = MultinomialNB()
model.fit(x_train_vetor, y_train)

#validaçao do desempenho
y_pred = model.predict(x_test_vetor)
print("RELATÓRIO DE CLASSIFICAÇÃO")
print(f"Acurácia: {accuracy_score(y_test, y_pred) * 100:.2f}%")
print("\nRelatório de Classificação:\n", classification_report(y_test, y_pred))

#testando com frases novas
novos_relatos = [
    "Estou com febre e dor de cabeça",
    "Tenho tosse seca e dificuldade para respirar",
    "Sinto cansaço extremo e perda de olfato",
    "Estou com dor de garganta e coriza",
    "Tenho dor no corpo e falta de apetite"
]

frases_novas = vetor.transform(novos_relatos)
predicoes_novas = model.predict(frases_novas)
print("Predições para novas frases:\n", predicoes_novas)
# Out:
# RELATÓRIO DE CLASSIFICAÇÃO
# Acurácia: 98.00%
#
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#   alto risco       1.00      0.98      0.99        61
#  baixo risco       0.97      1.00      0.98        86
#  médio risco       0.98      0.94      0.96        53
#
#     accuracy                           0.98       200
#    macro avg       0.98      0.98      0.98       200
# weighted avg       0.98      0.98      0.98       200
#
# Predições para novas frases:
#  ['médio risco' 'alto risco' 'alto risco' 'baixo risco' 'alto risco']
